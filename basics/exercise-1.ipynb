# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()

client = OpenAI(
    api_key=os.getenv("OPENAI_API_KEY")
)

response = client.completions.create(
    model="gpt-3.5-turbo-instruct",
    prompt="다음을 영어로 번역하세요: 안녕하세요? 오늘 날씨가 참 좋군요!",
    max_tokens=256,
)

print(response.choices[0].text)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import os
# ----> 2 from dotenv import load_dotenv
#       3 from openai import OpenAI
#       5 load_dotenv()
#
# ModuleNotFoundError: No module named 'dotenv'

# %%
explorer.exe .
# Out:
#   Cell In[2], line 1
#     explorer.exe .
#                   ^
# SyntaxError: invalid syntax

# %%
# !pip install python-dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting python-dotenv
#   Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.2.2

# %%
# !pip3 install openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting openai
#   Downloading openai-2.37.0-py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 7.7 MB/s eta 0:00:0000:0100:01
# Collecting httpx<1,>=0.23.0
#   Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 KB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions<5,>=4.11 in /home/kang7/.local/lib/python3.10/site-packages (from openai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting sniffio
#   Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting jiter<1,>=0.10.0
#   Downloading jiter-0.14.0-cp310-cp310-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (347 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.4/347.4 KB 745.0 kB/s eta 0:00:00a 0:00:02
# Collecting tqdm>4
#   Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 KB 2.2 MB/s eta 0:00:00a 0:00:01
# Collecting pydantic<3,>=1.9.0
#   Downloading pydantic-2.13.4-py3-none-any.whl (472 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.3/472.3 KB 7.3 MB/s eta 0:00:00a 0:00:01
# Collecting anyio<5,>=3.5.0
#   Downloading anyio-4.13.0-py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.4/114.4 KB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/kang7/.local/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /usr/lib/python3/dist-packages (from anyio<5,>=3.5.0->openai) (3.3)
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 KB 15.2 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from httpx<1,>=0.23.0->openai) (2020.6.20)
# Collecting h11>=0.16
#   Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Collecting annotated-types>=0.6.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting typing-inspection>=0.4.2
#   Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Collecting pydantic-core==2.46.4
#   Downloading pydantic_core-2.46.4-cp310-cp310-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 12.4 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: typing-inspection, tqdm, sniffio, pydantic-core, jiter, h11, annotated-types, pydantic, httpcore, anyio, httpx, openai
# Successfully installed annotated-types-0.7.0 anyio-4.13.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 jiter-0.14.0 openai-2.37.0 pydantic-2.13.4 pydantic-core-2.46.4 sniffio-1.3.1 tqdm-4.67.3 typing-inspection-0.4.2
